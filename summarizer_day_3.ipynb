# %%
pip install requests

# %%
import requests

# === Use Your Actual API Key Securely ===
GROQ_API_KEY = "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"
MODEL_NAME = "llama3-70b-8192"
API_URL = "https://api.groq.com/openai/v1/chat/completions"

def summarize_article(article_text):
    prompt = f"""


Article:
\"\"\"
{article_text}
\"\"\"

Only provide the summary paragraph. Do not label the parts separately.
"""

    headers = {
        "Authorization": f"Bearer {GROQ_API_KEY}",
        "Content-Type": "application/json",
    }

    data = {
        "model": MODEL_NAME,
        "messages": [
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt},
        ],
        "temperature": 0.4,
        "max_tokens": 300,
    }

    response = requests.post(API_URL, headers=headers, json=data)

    if response.status_code == 200:
        return response.json()["choices"][0]["message"]["content"].strip()
    else:
        raise Exception(f"Error {response.status_code}: {response.text}")

if __name__ == "__main__":
    # Replace this with the path to your article file
    article_file = "/content/project_report_8.txt"

    with open(article_file, "r", encoding="utf-8") as file:
        article_text = file.read()

    try:
        summary = summarize_article(article_text)
        print("\n📄 Summarized Research Article:\n")
        print(summary)
    except Exception as e:
        print("\n❌ Error during summarization:")
        print(e)
# Out:
# 📄 Summarized Research Article:
#
# This study investigated the effects of sleep duration and quality on cognitive performance in college-aged individuals. The results showed that students who slept 7-9 hours per night outperformed those who slept less than 6 hours on tests of memory, attention, and problem-solving skills. Additionally, students who reported higher sleep quality scored better on cognitive tests regardless of total sleep time. The findings suggest that both sleep quantity and quality are critical for cognitive performance, and improving sleep habits could be beneficial for academic achievement and mental efficiency.
